# %%
from __future__ import print_function
from umls.Authentication import *
import requests
import json
import argparse

# parser = argparse.ArgumentParser(description='process user given parameters')
# # parser.add_argument("-u", "--username", required =  True, dest="username", help = "enter username")
# # parser.add_argument("-p", "--password", required =  True, dest="password", help = "enter passowrd")
# parser.add_argument("-k", "--apikey", required=True, dest="apikey", help="enter api key from your UTS Profile")
# parser.add_argument("-v", "--version", required=False, dest="version", default="current", help="enter version example-2015AA")
# parser.add_argument("-s", "--source", required=True, dest="source", help="enter a source vocabulary, like 'SNOMEDCT_US'")
# parser.add_argument("-i", "--identifier", required=True, dest="identifier", help="enter an identifier, like 9468002")
# parser.add_argument("-o", "--operation", required=True, dest="operation",
# 					help="choose an operation such as 'children', 'parents', 'descendants', or 'ancestors'")

# args = parser.parse_args()
# # username = args.username
# # password = args.password
version = "current"
source = 'SNOMEDCT_US'
identifier = '9468002'
operation = 'children'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/content/" + version + "/source/" + source + "/" + identifier + "/" + operation

##get at ticket granting ticket for the session
AuthClient = Authentication()
tgt = AuthClient.gettgt()
pageNumber = 1

while True:

	query = {'ticket': AuthClient.getst(tgt), 'pageNumber': pageNumber}
	r = requests.get(uri + content_endpoint, params=query)
	print(r.url)
	r.encoding = 'utf-8'
	items = json.loads(r.text)
	pageCount = items["pageCount"]

	print("Results for page " + str(pageNumber) + "\n")
	for result in items["result"]:

		try:
			print("ui: " + result["ui"])
		except:
			NameError
		try:
			print("uri: " + result["uri"])
		except:
			NameError
		try:
			print("name: " + result["name"])
		except:
			NameError
		try:
			print("Source Vocabulary: " + result["rootSource"])
		except:
			NameError
		print("\n")
	pageNumber += 1

	if pageNumber > pageCount:
		print("End of result set")
		break

print("*********")
# Out:
# https://uts-ws.nlm.nih.gov/rest/content/current/source/SNOMEDCT_US/9468002/children?ticket=ST-191925-euJIOYgIJfCtTbMAM14F-cas&pageNumber=1
# Results for page 1
#
# ui: 10937721000119106
# name: Closed fracture of right wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 10937761000119101
# name: Closed fracture of left wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 208375001
# name: Closed fracture carpal bones, multiple
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 209267001
# name: Closed fracture dislocation midcarpal
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 209286009
# name: Closed fracture subluxation midcarpal
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 30632004
# name: Closed fracture of triquetral bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 357009
# name: Closed fracture of trapezoidal bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 37174005
# name: Closed fracture of hamate bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 37633006
# name: Closed fracture of lunate bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 42818005
# name: Closed fracture of scaphoid bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 43767005
# name: Closed fracture of pisiform bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 57114005
# name: Closed fracture of trapezium bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 90114000
# name: Closed fracture of capitate bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# End of result set
# *********

# %%
from __future__ import print_function
from Authentication import *
import requests
import json
import argparse
version = "current"
string = 'heart attack'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/search/"+version
##get at ticket granting ticket for the session
# AuthClient = Authentication()
tgt = AuthClient.gettgt()
pageNumber=0

while True:
    ##generate a new service ticket for each page if needed
    ticket = AuthClient.getst(tgt)
    pageNumber += 1
    query = {'string':string,'ticket':ticket, 'pageNumber':pageNumber}
    #query['includeObsolete'] = 'true'
    #query['includeSuppressible'] = 'true'
    #query['returnIdType'] = "sourceConcept"
    #query['sabs'] = "SNOMEDCT_US"
    r = requests.get(uri+content_endpoint,params=query)
    r.encoding = 'utf-8'
    items  = json.loads(r.text)
    jsonData = items["result"]
    #print (json.dumps(items, indent = 4))

    print("Results for page " + str(pageNumber)+"\n")
    
    for result in jsonData["results"]:
        print(result)
#       try:
#         print("ui: " + result["ui"])
#       except:
#         NameError
#       try:
#         print("uri: " + result["uri"])
#       except:
#         NameError
#       try:
#         print("name: " + result["name"])
#       except:
#         NameError
#       try:
#         print("Source Vocabulary: " + result["rootSource"])
#       except:
#         NameError
      
        print("\n")
        
    
    ##Either our search returned nothing, or we're at the end
    if jsonData["results"][0]["ui"] == "NONE":
        break
print("*********")
# Out:
# Results for page 1
#
# {'ui': 'C0027051', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0027051', 'name': 'Myocardial Infarction'}
#
#
# {'ui': 'C0155668', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155668', 'name': 'Old myocardial infarction'}
#
#
# {'ui': 'C0262568', 'rootSource': 'SNOMEDCT_US', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0262568', 'name': 'Subendocardial myocardial infarction'}
#
#
# {'ui': 'C0340293', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0340293', 'name': 'Anterior myocardial infarction'}
#
#
# {'ui': 'C0424154', 'rootSource': 'SNOMEDCT_US', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0424154', 'name': 'Fear of having a heart attack'}
#
#
# {'ui': 'C0497237', 'rootSource': 'SNOMEDCT_US', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0497237', 'name': 'Fear of heart attack'}
#
#
# {'ui': 'C2015875', 'rootSource': 'MEDCIN', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015875', 'name': 'outcomes cardiology likelihood of heart attack'}
#
#
# {'ui': 'C2926099', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926099', 'name': 'Ever told by doctor that you had a myocardial infarction or heart attack:Finding:Point in time:^Patient:Ordinal'}
#
#
# {'ui': 'C3843082', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3843082', 'name': 'Heart attack or M.I.'}
#
#
# {'ui': 'C0457037', 'rootSource': 'SNOMEDCT_US', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0457037', 'name': 'Anxiety about having a heart attack'}
#
#
# {'ui': 'C2024803', 'rootSource': 'MEDCIN', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2024803', 'name': 'cardiology goal to reduce likelihood of heart attack'}
#
#
# {'ui': 'C2925937', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2925937', 'name': 'Since your last exam told by a doctor you had a heart attack:Finding:Point in time:^Patient:Ordinal'}
#
#
# {'ui': 'C3169380', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3169380', 'name': 'PhenX - family history heart attack protocol:-:Point in time:^Patient:-:PhenX'}
#
#
# {'ui': 'C2015876', 'rootSource': 'MEDCIN', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015876', 'name': 'outcomes cardiology likelihood of heart attack increased'}
#
#
# {'ui': 'C2015877', 'rootSource': 'MEDCIN', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015877', 'name': 'outcomes cardiology likelihood of heart attack reduced'}
#
#
# {'ui': 'C2015878', 'rootSource': 'MEDCIN', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015878', 'name': 'outcomes cardiology likelihood of heart attack unchanged'}
#
#
# {'ui': 'C2924184', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924184', 'name': 'Age when the first heart attack occurred'}
#
#
# {'ui': 'C2925911', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2925911', 'name': 'Mother, father, full-blooded sisters, full-blooded brothers, daughters, or sons ever have a heart attack or myocardial infarction:Finding:Point in time:^Patient:Ordinal'}
#
#
# {'ui': 'C2926022', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926022', 'name': 'Age when the first heart attack occurred:Find:Pt:^Brother:Ord'}
#
#
# {'ui': 'C2926103', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926103', 'name': 'Age when the first heart attack occurred:Find:Pt:^Sister:Ord'}
#
#
# {'ui': 'C2926105', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926105', 'name': 'Age when the first heart attack occurred:Find:Pt:^Daughter:Ord'}
#
#
# {'ui': 'C2926106', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926106', 'name': 'Age when the first heart attack occurred:Find:Pt:^Son:Ord'}
#
#
# {'ui': 'C2926107', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926107', 'name': 'Age when the first heart attack occurred:Find:Pt:Father:Ord'}
#
#
# {'ui': 'C2926108', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926108', 'name': 'Age when the first heat attack occurred:Finding:Point in time:Mother:Ordinal'}
#
#
# {'ui': 'C2964322', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2964322', 'name': 'PhenX measure - family history of heart attack'}
#
#
# Results for page 2
#
# {'ui': 'C3165681', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3165681', 'name': 'PhenX - family history heart attack protocol'}
#
#
# {'ui': 'C3844360', 'rootSource': 'LNC', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3844360', 'name': "Don't know if he or she had a heart attack"}
#
#
# {'ui': 'C4288520', 'rootSource': 'NCI', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4288520', 'name': 'PHQ Screener Version - Anxiety Attack Heart Race or Pound'}
#
#
# {'ui': 'C3513527', 'rootSource': 'CPT', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3513527', 'name': 'Repair of lower heart chamber defect following heart attack'}
#
#
# {'ui': 'C3516129', 'rootSource': 'CPT', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3516129', 'name': 'Nuclear medicine study of heart muscle following heart attack'}
#
#
# {'ui': 'C2024773', 'rootSource': 'MEDCIN', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2024773', 'name': 'cardiac procedure limitations and risks discussed include residual risk of heart attack'}
#
#
# {'ui': 'C2924341', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924341', 'name': 'Ever told by doctor that you had a myocardial infarction or heart attack'}
#
#
# {'ui': 'C2924547', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924547', 'name': 'Since your last exam told by a doctor you had a heart attack'}
#
#
# {'ui': 'C2926026', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926026', 'name': 'PhenX measure - family history of heart attack:-:Point in time:^Patient:-:PhenX'}
#
#
# {'ui': 'C3527491', 'rootSource': 'CPT', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3527491', 'name': 'Nuclear medicine study of heart muscle following heart attack with evaluation of blood ejection from heart'}
#
#
# {'ui': 'C2585876', 'rootSource': 'SNOMEDCT_US', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2585876', 'name': 'CHADS2 score'}
#
#
# {'ui': 'C2924475', 'rootSource': 'MTH', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924475', 'name': 'Mother, father, full-blooded sisters, full-blooded brothers, daughters, or sons ever have a heart attack or myocardial infarction'}
#
#
# {'ui': 'C3704023', 'rootSource': 'CPT', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3704023', 'name': 'Insertion of stent, removal of plaque and/or balloon dilation of coronary vessel during heart attack, accessed through the skin'}
#
#
# {'ui': 'C4049268', 'rootSource': 'SNOMEDCT_US', 'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4049268', 'name': 'CHA2DS2-VASc score'}
#
#
# Results for page 3
#
# {'ui': 'NONE', 'name': 'NO RESULTS'}
#
#
# *********

# %%
os.path.isfile('../conf/smartanno_conf.json')
# Out:
# True

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# '/uufs/chpc.utah.edu/common/home/u0876964/Documents/PycharmProjects/SmartAnno/src/umls'
