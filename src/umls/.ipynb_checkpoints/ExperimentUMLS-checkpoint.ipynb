# %%
from __future__ import print_function
from umls.Authentication import *
import requests
import json
import argparse

# parser = argparse.ArgumentParser(description='process user given parameters')
# # parser.add_argument("-u", "--username", required =  True, dest="username", help = "enter username")
# # parser.add_argument("-p", "--password", required =  True, dest="password", help = "enter passowrd")
# parser.add_argument("-k", "--apikey", required=True, dest="apikey", help="enter api key from your UTS Profile")
# parser.add_argument("-v", "--version", required=False, dest="version", default="current", help="enter version example-2015AA")
# parser.add_argument("-s", "--source", required=True, dest="source", help="enter a source vocabulary, like 'SNOMEDCT_US'")
# parser.add_argument("-i", "--identifier", required=True, dest="identifier", help="enter an identifier, like 9468002")
# parser.add_argument("-o", "--operation", required=True, dest="operation",
# 					help="choose an operation such as 'children', 'parents', 'descendants', or 'ancestors'")

# args = parser.parse_args()
# # username = args.username
# # password = args.password
version = "current"
source = 'SNOMEDCT_US'
identifier = '9468002'
operation = 'children'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/content/" + version + "/source/" + source + "/" + identifier + "/" + operation

##get at ticket granting ticket for the session
AuthClient = Authentication()
tgt = AuthClient.gettgt()
pageNumber = 1

while True:

	query = {'ticket': AuthClient.getst(tgt), 'pageNumber': pageNumber}
	r = requests.get(uri + content_endpoint, params=query)
	print(r.url)
	r.encoding = 'utf-8'
	items = json.loads(r.text)
	pageCount = items["pageCount"]

	print("Results for page " + str(pageNumber) + "\n")
	for result in items["result"]:

		try:
			print("ui: " + result["ui"])
		except:
			NameError
		try:
			print("uri: " + result["uri"])
		except:
			NameError
		try:
			print("name: " + result["name"])
		except:
			NameError
		try:
			print("Source Vocabulary: " + result["rootSource"])
		except:
			NameError
		print("\n")
	pageNumber += 1

	if pageNumber > pageCount:
		print("End of result set")
		break

print("*********")
# Out:
# https://uts-ws.nlm.nih.gov/rest/content/current/source/SNOMEDCT_US/9468002/children?ticket=ST-191925-euJIOYgIJfCtTbMAM14F-cas&pageNumber=1
# Results for page 1
#
# ui: 10937721000119106
# name: Closed fracture of right wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 10937761000119101
# name: Closed fracture of left wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 208375001
# name: Closed fracture carpal bones, multiple
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 209267001
# name: Closed fracture dislocation midcarpal
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 209286009
# name: Closed fracture subluxation midcarpal
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 30632004
# name: Closed fracture of triquetral bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 357009
# name: Closed fracture of trapezoidal bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 37174005
# name: Closed fracture of hamate bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 37633006
# name: Closed fracture of lunate bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 42818005
# name: Closed fracture of scaphoid bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 43767005
# name: Closed fracture of pisiform bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 57114005
# name: Closed fracture of trapezium bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: 90114000
# name: Closed fracture of capitate bone of wrist
# Source Vocabulary: SNOMEDCT_US
#
#
# End of result set
# *********

# %%
from __future__ import print_function
from Authentication import *
import requests
import json
import argparse
version = "current"
string = 'heart attack'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/search/"+version
##get at ticket granting ticket for the session
# AuthClient = Authentication()
tgt = AuthClient.gettgt()
pageNumber=0

while True:
    ##generate a new service ticket for each page if needed
    ticket = AuthClient.getst(tgt)
    pageNumber += 1
    query = {'string':string,'ticket':ticket, 'pageNumber':pageNumber}
    #query['includeObsolete'] = 'true'
    #query['includeSuppressible'] = 'true'
    #query['returnIdType'] = "sourceConcept"
    #query['sabs'] = "SNOMEDCT_US"
    r = requests.get(uri+content_endpoint,params=query)
    r.encoding = 'utf-8'
    items  = json.loads(r.text)
    jsonData = items["result"]
    #print (json.dumps(items, indent = 4))

    print("Results for page " + str(pageNumber)+"\n")
    
    for result in jsonData["results"]:
        print(result)
      try:
        print("ui: " + result["ui"])
      except:
        NameError
      try:
        print("uri: " + result["uri"])
      except:
        NameError
      try:
        print("name: " + result["name"])
      except:
        NameError
      try:
        print("Source Vocabulary: " + result["rootSource"])
      except:
        NameError
      
      print("\n")
        
    
    ##Either our search returned nothing, or we're at the end
    if jsonData["results"][0]["ui"] == "NONE":
        break
print("*********")
# Out:
# Results for page 1
#
# ui: C0027051
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0027051
# name: Myocardial Infarction
# Source Vocabulary: MTH
#
#
# ui: C0155668
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155668
# name: Old myocardial infarction
# Source Vocabulary: MTH
#
#
# ui: C0262568
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0262568
# name: Subendocardial myocardial infarction
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0340293
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0340293
# name: Anterior myocardial infarction
# Source Vocabulary: MTH
#
#
# ui: C0424154
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0424154
# name: Fear of having a heart attack
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0497237
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0497237
# name: Fear of heart attack
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2015875
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015875
# name: outcomes cardiology likelihood of heart attack
# Source Vocabulary: MEDCIN
#
#
# ui: C2926099
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926099
# name: Ever told by doctor that you had a myocardial infarction or heart attack:Finding:Point in time:^Patient:Ordinal
# Source Vocabulary: MTH
#
#
# ui: C3843082
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3843082
# name: Heart attack or M.I.
# Source Vocabulary: LNC
#
#
# ui: C0457037
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0457037
# name: Anxiety about having a heart attack
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2024803
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2024803
# name: cardiology goal to reduce likelihood of heart attack
# Source Vocabulary: MEDCIN
#
#
# ui: C2925937
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2925937
# name: Since your last exam told by a doctor you had a heart attack:Finding:Point in time:^Patient:Ordinal
# Source Vocabulary: MTH
#
#
# ui: C3169380
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3169380
# name: PhenX - family history heart attack protocol:-:Point in time:^Patient:-:PhenX
# Source Vocabulary: MTH
#
#
# ui: C2015876
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015876
# name: outcomes cardiology likelihood of heart attack increased
# Source Vocabulary: MEDCIN
#
#
# ui: C2015877
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015877
# name: outcomes cardiology likelihood of heart attack reduced
# Source Vocabulary: MEDCIN
#
#
# ui: C2015878
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2015878
# name: outcomes cardiology likelihood of heart attack unchanged
# Source Vocabulary: MEDCIN
#
#
# ui: C2924184
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924184
# name: Age when the first heart attack occurred
# Source Vocabulary: LNC
#
#
# ui: C2925911
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2925911
# name: Mother, father, full-blooded sisters, full-blooded brothers, daughters, or sons ever have a heart attack or myocardial infarction:Finding:Point in time:^Patient:Ordinal
# Source Vocabulary: MTH
#
#
# ui: C2926022
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926022
# name: Age when the first heart attack occurred:Find:Pt:^Brother:Ord
# Source Vocabulary: LNC
#
#
# ui: C2926103
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926103
# name: Age when the first heart attack occurred:Find:Pt:^Sister:Ord
# Source Vocabulary: LNC
#
#
# ui: C2926105
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926105
# name: Age when the first heart attack occurred:Find:Pt:^Daughter:Ord
# Source Vocabulary: LNC
#
#
# ui: C2926106
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926106
# name: Age when the first heart attack occurred:Find:Pt:^Son:Ord
# Source Vocabulary: LNC
#
#
# ui: C2926107
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926107
# name: Age when the first heart attack occurred:Find:Pt:Father:Ord
# Source Vocabulary: LNC
#
#
# ui: C2926108
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926108
# name: Age when the first heat attack occurred:Finding:Point in time:Mother:Ordinal
# Source Vocabulary: MTH
#
#
# ui: C2964322
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2964322
# name: PhenX measure - family history of heart attack
# Source Vocabulary: MTH
#
#
# Results for page 2
#
# ui: C3165681
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3165681
# name: PhenX - family history heart attack protocol
# Source Vocabulary: MTH
#
#
# ui: C3844360
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3844360
# name: Don't know if he or she had a heart attack
# Source Vocabulary: LNC
#
#
# ui: C4288520
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4288520
# name: PHQ Screener Version - Anxiety Attack Heart Race or Pound
# Source Vocabulary: NCI
#
#
# ui: C3513527
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3513527
# name: Repair of lower heart chamber defect following heart attack
# Source Vocabulary: CPT
#
#
# ui: C3516129
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3516129
# name: Nuclear medicine study of heart muscle following heart attack
# Source Vocabulary: CPT
#
#
# ui: C2024773
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2024773
# name: cardiac procedure limitations and risks discussed include residual risk of heart attack
# Source Vocabulary: MEDCIN
#
#
# ui: C2924341
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924341
# name: Ever told by doctor that you had a myocardial infarction or heart attack
# Source Vocabulary: MTH
#
#
# ui: C2924547
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924547
# name: Since your last exam told by a doctor you had a heart attack
# Source Vocabulary: MTH
#
#
# ui: C2926026
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2926026
# name: PhenX measure - family history of heart attack:-:Point in time:^Patient:-:PhenX
# Source Vocabulary: MTH
#
#
# ui: C3527491
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3527491
# name: Nuclear medicine study of heart muscle following heart attack with evaluation of blood ejection from heart
# Source Vocabulary: CPT
#
#
# ui: C2585876
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2585876
# name: CHADS2 score
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2924475
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2924475
# name: Mother, father, full-blooded sisters, full-blooded brothers, daughters, or sons ever have a heart attack or myocardial infarction
# Source Vocabulary: MTH
#
#
# ui: C3704023
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3704023
# name: Insertion of stent, removal of plaque and/or balloon dilation of coronary vessel during heart attack, accessed through the skin
# Source Vocabulary: CPT
#
#
# ui: C4049268
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4049268
# name: CHA2DS2-VASc score
# Source Vocabulary: SNOMEDCT_US
#
#
# Results for page 3
#
# ui: NONE
# name: NO RESULTS
#
#
# *********

# %%
os.path.isfile('../conf/smartanno_conf.json')
# Out:
# True

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# '/uufs/chpc.utah.edu/common/home/u0876964/Documents/PycharmProjects/SmartAnno/src/umls'
