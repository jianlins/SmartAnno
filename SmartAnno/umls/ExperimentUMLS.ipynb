# %%
from __future__ import print_function
from umls.Authentication import *
import requests
import json
import argparse

# parser = argparse.ArgumentParser(description='process user given parameters')
# # parser.add_argument("-u", "--username", required =  True, dest="username", help = "enter username")
# # parser.add_argument("-p", "--password", required =  True, dest="password", help = "enter passowrd")
# parser.add_argument("-k", "--apikey", required=True, dest="apikey", help="enter api key from your UTS Profile")
# parser.add_argument("-v", "--version", required=False, dest="version", default="current", help="enter version example-2015AA")
# parser.add_argument("-s", "--source", required=True, dest="source", help="enter a source vocabulary, like 'SNOMEDCT_US'")
# parser.add_argument("-i", "--identifier", required=True, dest="identifier", help="enter an identifier, like 9468002")
# parser.add_argument("-o", "--operation", required=True, dest="operation",
# 					help="choose an operation such as 'children', 'parents', 'descendants', or 'ancestors'")

# args = parser.parse_args()
# # username = args.username
# # password = args.password
version = "current"
source = 'SNOMEDCT_US'
identifier = '9468002'
operation = 'children'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/content/" + version + "/source/" + source + "/" + identifier + "/" + operation

##get at ticket granting ticket for the session
AuthClient = Authentication()
tgt = AuthClient.gettgt()
pageNumber = 1

while True:

	query = {'ticket': AuthClient.getst(tgt), 'pageNumber': pageNumber}
	r = requests.get(uri + content_endpoint, params=query)
	print(r.url)
	r.encoding = 'utf-8'
	items = json.loads(r.text)
	pageCount = items["pageCount"]

	print("Results for page " + str(pageNumber) + "\n")
	for result in items["result"]:

		try:
			print("ui: " + result["ui"])
		except:
			NameError
		try:
			print("uri: " + result["uri"])
		except:
			NameError
		try:
			print("name: " + result["name"])
		except:
			NameError
		try:
			print("Source Vocabulary: " + result["rootSource"])
		except:
			NameError
		print("\n")
	pageNumber += 1

	if pageNumber > pageCount:
		print("End of result set")
		break

print("*********")

# %%
from __future__ import print_function
from umls.Authentication import *
import requests
import json
import argparse
version = "current"
string = 'heart attack'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/search/"+version
##get at ticket granting ticket for the session
# AuthClient = Authentication()
tgt = AuthClient.gettgt()
pageNumber=0

while True:
    ##generate a new service ticket for each page if needed
    ticket = AuthClient.getst(tgt)
    pageNumber += 1
    query = {'string':string,'ticket':ticket, 'pageNumber':pageNumber}
    #query['includeObsolete'] = 'true'
    #query['includeSuppressible'] = 'true'
    #query['returnIdType'] = "sourceConcept"
    #query['sabs'] = "SNOMEDCT_US"
    r = requests.get(uri+content_endpoint,params=query)
    r.encoding = 'utf-8'
    items  = json.loads(r.text)
    jsonData = items["result"]
    #print (json.dumps(items, indent = 4))

    print("Results for page " + str(pageNumber)+"\n")
    
    for result in jsonData["results"]:
        print(result)
#       try:
#         print("ui: " + result["ui"])
#       except:
#         NameError
#       try:
#         print("uri: " + result["uri"])
#       except:
#         NameError
#       try:
#         print("name: " + result["name"])
#       except:
#         NameError
#       try:
#         print("Source Vocabulary: " + result["rootSource"])
#       except:
#         NameError
      
        print("\n")
        
    
    ##Either our search returned nothing, or we're at the end
    if jsonData["results"][0]["ui"] == "NONE":
        break
print("*********")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-59e04813b193> in <module>()
#      11 ##get at ticket granting ticket for the session
#      12 # AuthClient = Authentication()
# ---> 13 tgt = AuthClient.gettgt()
#      14 pageNumber=0
#      15
#
# NameError: name 'AuthClient' is not defined

# %%
from __future__ import print_function
from umls.Authentication import *
import requests
import json
import argparse


#username = args.username
#password = args.password

version = 'current'
string = 'heart failure'
uri = "https://uts-ws.nlm.nih.gov"
content_endpoint = "/rest/search/"+version
##get at ticket granting ticket for the session
AuthClient = Authentication(ConfigReader('../conf/smartanno_conf.json').getValue('api_key'))
tgt = AuthClient.gettgt()
pageNumber=0

while True:
    ##generate a new service ticket for each page if needed
    ticket = AuthClient.getst(tgt)
    pageNumber += 1
    query = {'string':string,'ticket':ticket, 'pageNumber':pageNumber}
    #query['includeObsolete'] = 'true'
    #query['includeSuppressible'] = 'true'
    #query['returnIdType'] = "sourceConcept"
    #query['sabs'] = "SNOMEDCT_US"
    r = requests.get(uri+content_endpoint,params=query)
    r.encoding = 'utf-8'
    items  = json.loads(r.text)
    jsonData = items["result"]
    #print (json.dumps(items, indent = 4))

    print("Results for page " + str(pageNumber)+"\n")
    
    for result in jsonData["results"]:
        
      try:
        print("ui: " + result["ui"])
      except:
        NameError
      try:
        print("uri: " + result["uri"])
      except:
        NameError
      try:
        print("name: " + result["name"])
      except:
        NameError
      try:
        print("Source Vocabulary: " + result["rootSource"])
      except:
        NameError
      
      print("\n")
        
    
    ##Either our search returned nothing, or we're at the end
    if jsonData["results"][0]["ui"] == "NONE":
        break
    print("*********")
# Out:
# Results for page 1
#
# ui: C0018801
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0018801
# name: Heart failure
# Source Vocabulary: MTH
#
#
# ui: C0018802
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0018802
# name: Congestive heart failure
# Source Vocabulary: MTH
#
#
# ui: C0494575
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0494575
# name: Hypertensive heart and renal disease with (congestive) heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1392020
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1392020
# name: failure; cardiorenal, hypertensive, with renal failure, and heart failure
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C0264723
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264723
# name: Right heart failure secondary to left heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3698379
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3698379
# name: Congestive heart failure with right heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4509242
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509242
# name: Right heart failure due to left heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C1400066
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1400066
# name: Hypertensive heart disease with heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0023212
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0023212
# name: Left-Sided Heart Failure
# Source Vocabulary: MTH
#
#
# ui: C0155582
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155582
# name: Congestive rheumatic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0221045
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0221045
# name: High output heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0235527
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0235527
# name: Heart Failure, Right-Sided
# Source Vocabulary: MTH
#
#
# ui: C0264652
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264652
# name: Hypertensive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264714
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264714
# name: Acute heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264715
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264715
# name: Acute right-sided heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264716
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264716
# name: Chronic heart failure
# Source Vocabulary: MTH
#
#
# ui: C0264719
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264719
# name: Acute congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264722
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264722
# name: Chronic congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264725
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264725
# name: Acute left-sided heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264728
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264728
# name: Low output heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264731
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264731
# name: Cardiac insufficiency due to prosthesis
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264762
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264762
# name: Rheumatic heart valve failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0333633
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0333633
# name: Hemosiderin-laden macrophage
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0340510
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0340510
# name: Heart failure as a complication of care
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0340531
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0340531
# name: Cardiac transplant failure
# Source Vocabulary: SNOMEDCT_US
#
#
# *********
# Results for page 2
#
# ui: C0348882
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0348882
# name: Heart transplant failure and rejection
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0410933
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0410933
# name: Congenital cardiac failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0455531
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0455531
# name: H/O: heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0455993
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0455993
# name: Neonatal cardiac failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0581377
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0581377
# name: Decompensated cardiac failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0685095
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0685095
# name: Biventricular congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0742744
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742744
# name: CONGESTIVE HEART FAILURE CLINICAL
# Source Vocabulary: CCPSS
#
#
# ui: C0742745
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742745
# name: CONGESTIVE HEART FAILURE COMPENSATED
# Source Vocabulary: CCPSS
#
#
# ui: C0742746
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742746
# name: CONGESTIVE HEART FAILURE DECOMPENSATED
# Source Vocabulary: CCPSS
#
#
# ui: C0742748
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742748
# name: CONGESTIVE HEART FAILURE IATROGENIC
# Source Vocabulary: CCPSS
#
#
# ui: C0742751
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742751
# name: CONGESTIVE HEART FAILURE MULTIFACTORIAL
# Source Vocabulary: CCPSS
#
#
# ui: C0742753
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742753
# name: CONGESTIVE HEART FAILURE NO DOCUMENTATION
# Source Vocabulary: CCPSS
#
#
# ui: C0742754
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742754
# name: CONGESTIVE HEART FAILURE RECURRENT
# Source Vocabulary: CCPSS
#
#
# ui: C0742758
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742758
# name: Symptomatic congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0742760
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742760
# name: CONGESTIVE HEART FAILURE TREATED
# Source Vocabulary: CCPSS
#
#
# ui: C0810005
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0810005
# name: Congestive heart failure; nonhypertensive
# Source Vocabulary: CCS_10
#
#
# ui: C0851638
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0851638
# name: Heart failure signs and symptoms
# Source Vocabulary: MDR
#
#
# ui: C1135191
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135191
# name: Heart Failure, Systolic
# Source Vocabulary: MSH
#
#
# ui: C1135194
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135194
# name: Chronic systolic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1135196
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135196
# name: Heart Failure, Diastolic
# Source Vocabulary: MSH
#
#
# ui: C1271080
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1271080
# name: Heart failure excluded
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1271084
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1271084
# name: Suspected heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1271093
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1271093
# name: Heart failure confirmed
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1272198
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1272198
# name: Heart failure screen
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1272214
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1272214
# name: Heart failure follow-up
# Source Vocabulary: SNOMEDCT_US
#
#
# *********
# Results for page 3
#
# ui: C1272215
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1272215
# name: Heart failure annual review
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1276352
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1276352
# name: Congestive heart failure monitoring
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1277209
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1277209
# name: Referral to heart failure clinic
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1281998
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1281998
# name: Refractory heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1399214
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1399214
# name: heart failure; with decompensation
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1404114
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1404114
# name: Heart-lung transplant failure
# Source Vocabulary: MEDCIN
#
#
# ui: C1563224
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1563224
# name: Seen in heart failure clinic
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1563256
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1563256
# name: Referral to heart failure nurse
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1609524
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1609524
# name: ADHF
# Source Vocabulary: MDR
#
#
# ui: C1827266
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1827266
# name: Decompensated chronic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1828111
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1828111
# name: Heart failure education
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1832374
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1832374
# name: Restrictive heart failure
# Source Vocabulary: HPO
#
#
# ui: C1875347
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1875347
# name: INVESTIGATIONAL CONGESTIVE HEART FAILURE
# Source Vocabulary: VANDF
#
#
# ui: C2039715
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2039715
# name: systolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2047098
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2047098
# name: hospital discharge instructions for heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2183328
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2183328
# name: diastolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2317056
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2317056
# name: Family history of heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2321819
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2321819
# name: sample template heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2363704
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2363704
# name: Congestive Heart Failure Analyzers
# Source Vocabulary: UMD
#
#
# ui: C2708655
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2708655
# name: Heart failure tracking panel:-:Point in time:^Patient:-
# Source Vocabulary: MTH
#
#
# ui: C2708656
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2708656
# name: Heart failure tracking panel
# Source Vocabulary: MTH
#
#
# ui: C2711480
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2711480
# name: Chronic diastolic heart failure
# Source Vocabulary: MTH
#
#
# ui: C2732748
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2732748
# name: Acute systolic heart failure
# Source Vocabulary: MTH
#
#
# ui: C2732951
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2732951
# name: Acute diastolic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2735647
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2735647
# name: Symptoms in heart failure patients
# Source Vocabulary: LNC
#
#
# *********
# Results for page 4
#
# ui: C2737028
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2737028
# name: Heart failure in last 7D
# Source Vocabulary: LNC
#
#
# ui: C2825210
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2825210
# name: Heart Failure During Hospitalization
# Source Vocabulary: NCI
#
#
# ui: C2882269
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882269
# name: Edema of lung with heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C2887330
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2887330
# name: Postprocedural heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C2939447
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2939447
# name: Right ventricular failure
# Source Vocabulary: MTH
#
#
# ui: C3176375
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3176375
# name: Heart failure 4Y risk
# Source Vocabulary: LNC
#
#
# ui: C3244195
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3244195
# name: certified heart failure care
# Source Vocabulary: HL7V3.0
#
#
# ui: C3266215
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3266215
# name: Heart failure medication review
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3532172
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532172
# name: Fetal heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3532952
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532952
# name: Exacerbation of congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3662024
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3662024
# name: Diastolic heart failure stage A
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3662026
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3662026
# name: Systolic heart failure stage A
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3662280
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3662280
# name: At high risk for heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3662281
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3662281
# name: At risk for heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3829662
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3829662
# name: Hospitalized or Treated for Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3838757
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3838757
# name: Congestive heart failure clinic
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3896989
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3896989
# name: Heart Failure Therapy Intensification Type
# Source Vocabulary: NCI
#
#
# ui: C3898772
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898772
# name: Increase in B-type Natriuretic Peptide or N-terminal pro-B-type Natriuretic Peptide
# Source Vocabulary: NCI
#
#
# ui: C3898876
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898876
# name: Hospitalization Due to Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3899311
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3899311
# name: ER or Office Visit Due to Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C4064965
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4064965
# name: heart failure assessed
# Source Vocabulary: MEDCIN
#
#
# ui: C4087508
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4087508
# name: Acute on chronic heart failure
# Source Vocabulary: MDR
#
#
# ui: C4275081
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4275081
# name: Heart failure education not done
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4313263
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4313263
# name: Heart failure (patient A)
# Source Vocabulary: OMIM
#
#
# ui: C4478914
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4478914
# name: Congestive heart failure at presentation
# Source Vocabulary: OMIM
#
#
# *********
# Results for page 5
#
# ui: C4509229
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509229
# name: Other heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509230
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509230
# name: Right heart failure, unspecified
# Source Vocabulary: ICD10CM
#
#
# ui: C4509234
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509234
# name: Chronic right heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509244
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509244
# name: End stage heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509245
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509245
# name: Stage D heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C0155606
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155606
# name: malignant hypertensive heart and renal disease with congestive heart failure and renal failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0155611
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155611
# name: benign hypertensive heart and renal disease with congestive heart failure and renal failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0494576
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0494576
# name: Hypertensive heart and renal disease with both (congestive) heart failure and renal failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1400068
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1400068
# name: hypertensive heart disease; with hypertensive kidney disease, with renal failure and heart failure
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C2047552
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2047552
# name: hypertensive heart and renal disease with congestive heart failure and renal failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2047553
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2047553
# name: hypertensive heart and renal disease without congestive heart failure or renal failure
# Source Vocabulary: MEDCIN
#
#
# ui: C4509231
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509231
# name: Right heart failure without mention of left heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C0155586
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155586
# name: Malignant hypertensive heart disease with congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0155589
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155589
# name: Benign hypertensive heart disease with congestive cardiac failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0155591
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155591
# name: Hypertensive heart disease NOS without congestive cardiac failure
# Source Vocabulary: MTH
#
#
# ui: C0155609
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155609
# name: benign hypertensive heart and renal disease with congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0264650
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264650
# name: Hypertensive heart disease with congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1135328
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135328
# name: malignant hypertensive heart disease without heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C1135329
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135329
# name: malignant hypertensive heart disease with heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C1135330
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135330
# name: benign hypertensive heart disease without heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C1135331
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135331
# name: benign hypertensive heart disease with heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C1135332
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135332
# name: Unspecified hypertensive heart disease without heart failure
# Source Vocabulary: ICD9CM
#
#
# ui: C1135333
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1135333
# name: Unspecified hypertensive heart disease with heart failure
# Source Vocabulary: ICD9CM
#
#
# ui: C1400052
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1400052
# name: hypertension; heart disease, hypertensive, with heart failure
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C2882075
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882075
# name: Hypertensive heart disease without heart failure
# Source Vocabulary: MEDCIN
#
#
# *********
# Results for page 6
#
# ui: C3665458
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3665458
# name: Hypertensive heart AND chronic kidney disease with congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264717
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264717
# name: Chronic right-sided heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264721
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264721
# name: Acute left-sided congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264726
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264726
# name: Chronic left-sided heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264730
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264730
# name: Cardiac insufficiency following cardiac surgery
# Source Vocabulary: MTH
#
#
# ui: C0264785
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264785
# name: Rheumatic left ventricular failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0348883
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0348883
# name: Heart-lung transplant failure and rejection
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0587124
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0587124
# name: H/O: Heart failure in last year
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0742743
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742743
# name: CONGESTIVE HEART FAILURE ACUTE EXACERBATION
# Source Vocabulary: CCPSS
#
#
# ui: C0742747
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742747
# name: High-output congestive heart failure
# Source Vocabulary: HPO
#
#
# ui: C0742749
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742749
# name: left sided congestive heart failure
# Source Vocabulary: MTH
#
#
# ui: C0742752
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742752
# name: CONGESTIVE HEART FAILURE NEW ONSET
# Source Vocabulary: CCPSS
#
#
# ui: C0742755
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742755
# name: right-sided congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0742759
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742759
# name: CONGESTIVE HEART FAILURE SYSTOLIC DYSFUNCTION
# Source Vocabulary: CCPSS
#
#
# ui: C1406955
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1406955
# name: thyrotoxic; heart disease or failure (manifestation)
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1536130
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1536130
# name: Heart failure NYHA class I
# Source Vocabulary: MDR
#
#
# ui: C1536131
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1536131
# name: Heart failure NYHA class II
# Source Vocabulary: MDR
#
#
# ui: C1536132
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1536132
# name: Heart failure NYHA class III
# Source Vocabulary: MDR
#
#
# ui: C1536133
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1536133
# name: Heart failure NYHA class IV
# Source Vocabulary: MDR
#
#
# ui: C1562135
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1562135
# name: Seen by community heart failure nurse
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1563075
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1563075
# name: Emergency hospital admission for heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1856703
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1856703
# name: Major cause of death is heart failure
# Source Vocabulary: OMIM
#
#
# ui: C1881906
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1881906
# name: Most Recent Heart Failure Event
# Source Vocabulary: NCI
#
#
# ui: C1968751
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1968751
# name: Congestive heart failure (in a subset of patients)
# Source Vocabulary: OMIM
#
#
# ui: C2007622
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2007622
# name: cardiac catheterization in-lab complication: congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# *********
# Results for page 7
#
# ui: C2077382
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2077382
# name: instrument failure during heart catheterization
# Source Vocabulary: MEDCIN
#
#
# ui: C2200400
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2200400
# name: rheumatic biventricular failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2200401
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2200401
# name: rheumatic right ventricular failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2215111
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2215111
# name: acute diastolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2315232
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2315232
# name: Family history of congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2732749
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2732749
# name: Acute on chronic diastolic heart failure
# Source Vocabulary: MTH
#
#
# ui: C2733492
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2733492
# name: Acute on chronic systolic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2882273
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882273
# name: Unspecified combined systolic (congestive) and diastolic (congestive) heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C2882277
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882277
# name: Cardiac, heart or myocardial failure NOS
# Source Vocabulary: ICD10CM
#
#
# ui: C2939049
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2939049
# name: Acute bi-ventricular heart failure
# Source Vocabulary: MDR
#
#
# ui: C2960127
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2960127
# name: Heart failure with normal ejection fraction
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2984177
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2984177
# name: Date of Most Recent Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3258487
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3258487
# name: Advanced heart failure and transplant cardiology
# Source Vocabulary: LNC
#
#
# ui: C3262558
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3262558
# name: Letter:Find:Pt:Hospital:Doc:Advanced heart failure and transplant cardiology
# Source Vocabulary: LNC
#
#
# ui: C3476112
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3476112
# name: Minnesota Living with Heart Failure Questionnaire
# Source Vocabulary: LNC
#
#
# ui: C3495092
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3495092
# name: Nutrition therapy for congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3508173
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3508173
# name: patient engagement: congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C3531728
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3531728
# name: Systolic heart failure stage D
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3531729
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3531729
# name: Systolic heart failure stage C
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3531730
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3531730
# name: Diastolic heart failure stage D
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3531731
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3531731
# name: Diastolic heart failure stage C
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3532173
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532173
# name: Fetal heart failure with myocardial hypertrophy
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3532936
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532936
# name: Congestive heart failure stage D
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3532937
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532937
# name: Congestive heart failure stage C
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3536548
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3536548
# name: Congestive heart failure stage B
# Source Vocabulary: SNOMEDCT_US
#
#
# *********
# Results for page 8
#
# ui: C3536668
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3536668
# name: Diastolic heart failure stage B
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3536669
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3536669
# name: Systolic heart failure stage B
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3551869
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3551869
# name: Congestive heart failure (in some patients)
# Source Vocabulary: OMIM
#
#
# ui: C3662279
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3662279
# name: High risk of heart failure, stage A
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3696922
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3696922
# name: Heart failure self management plan
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3697063
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3697063
# name: Acute exacerbation of chronic congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3697706
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3697706
# name: Congestive heart failure due to cardiomyopathy
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3809290
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3809290
# name: Heart failure (biventricular in some patients)
# Source Vocabulary: OMIM
#
#
# ui: C3809347
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3809347
# name: Heart failure, progressive and sometimes fatal
# Source Vocabulary: OMIM
#
#
# ui: C3839346
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3839346
# name: Heart failure with reduced ejection fraction
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3844449
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3844449
# name: Heart failure (e.g., fluid overload)
# Source Vocabulary: LNC
#
#
# ui: C3875300
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3875300
# name: Referral to heart failure exercise program
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3898899
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898899
# name: Heart Failure by Invasive Diagnostic Technique
# Source Vocabulary: NCI
#
#
# ui: C4024201
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4024201
# name: Low-output congestive heart failure
# Source Vocabulary: HPO
#
#
# ui: C4083073
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4083073
# name: acute systolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C4227507
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4227507
# name: Heart failure, associated with febrile illness
# Source Vocabulary: OMIM
#
#
# ui: C4509224
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509224
# name: Systolic left ventricular heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509225
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509225
# name: Diastolic left ventricular heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509232
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509232
# name: Acute isolated right heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509235
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509235
# name: Chronic isolated right heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509237
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509237
# name: Acute on chronic right heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C0034072
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0034072
# name: Cor pulmonale
# Source Vocabulary: MTH
#
#
# ui: C0155605
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155605
# name: malignant hypertensive heart and renal disease with renal failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0155610
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155610
# name: benign hypertensive heart and renal disease with renal failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0261559
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0261559
# name: Mechanical failure of instrument or apparatus during heart catheterization
# Source Vocabulary: SNOMEDCT_US
#
#
# *********
# Results for page 9
#
# ui: C0264546
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264546
# name: Pleural effusion due to congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264720
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264720
# name: Acute right-sided congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264724
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264724
# name: Chronic right-sided congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0264727
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0264727
# name: Chronic left-sided congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0274379
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0274379
# name: Cardiac insufficiency during AND/OR resulting from a procedure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0348879
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0348879
# name: Hypertensive heart and renal disease with renal failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0497083
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0497083
# name: Injury due to failure of sterile precautions during heart catheterization
# Source Vocabulary: MTH
#
#
# ui: C0513710
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0513710
# name: Monitor respiratory status for symptoms of heart failure
# Source Vocabulary: NIC
#
#
# ui: C0742750
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742750
# name: CONGESTIVE HEART FAILURE LEFT SIDED NEW ONSET
# Source Vocabulary: CCPSS
#
#
# ui: C0742756
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0742756
# name: CONGESTIVE HEART FAILURE RIGHT SIDED RECURRENT
# Source Vocabulary: CCPSS
#
#
# ui: C0865696
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0865696
# name: Heart failure following cardiac surgery or due to prosthesis
# Source Vocabulary: MTHICD9
#
#
# ui: C1274674
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1274674
# name: Red half-moon nail in congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1386189
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1386189
# name: rheumatic fever; inactive or quiescent with heart failure (congestive)
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1393255
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1393255
# name: heart; complications, transplant, failure or rejection, and lung(s)
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1394784
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1394784
# name: heart; decompensation, hypertensive, with renal disease and renal failure
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1403149
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1403149
# name: lung; edema, acute, with heart disease or failure
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1403188
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1403188
# name: lung transplant; complications, failure or rejection, with heart transplant
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C1716746
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1716746
# name: Congestive heart failure:Find:Pt:^Patient:Ord:MDS
# Source Vocabulary: LNC
#
#
# ui: C1854957
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1854957
# name: Death often secondary to pneumonia or congestive heart failure
# Source Vocabulary: OMIM
#
#
# ui: C1862676
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1862676
# name: Congestive heart failure (Detroit type 107680.0011)
# Source Vocabulary: OMIM
#
#
# ui: C1880778
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1880778
# name: First Ever Onset of Heart Failure Event
# Source Vocabulary: NCI
#
#
# ui: C1881035
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1881035
# name: Heart Failure Prompting Medical Attention Event
# Source Vocabulary: NCI
#
#
# ui: C1960038
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1960038
# name: Right heart failure due to pulmonary hypertension
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C1960707
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1960707
# name: Congestive heart failure due to valvular disease
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2007612
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2007612
# name: congestive heart failure as indication for cardiac catheterization
# Source Vocabulary: MEDCIN
#
#
# *********
# Results for page 10
#
# ui: C2008338
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2008338
# name: cardiac catheterization out-of-lab postprocedural complication: congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2062873
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2062873
# name: combined systolic and diastolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2073718
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2073718
# name: chronic combined systolic and diastolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2103696
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2103696
# name: class I left-sided congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2103697
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2103697
# name: class II left-sided congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2103698
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2103698
# name: class III left-sided congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2103699
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2103699
# name: class IV left-sided congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2107289
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2107289
# name: congestive heart failure as complication of obstetric anesthesia
# Source Vocabulary: MEDCIN
#
#
# ui: C2215102
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2215102
# name: acute combined systolic and diastolic congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C2231380
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2231380
# name: congestive heart failure as complication of obstetrical surgery
# Source Vocabulary: MEDCIN
#
#
# ui: C2585901
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2585901
# name: Knowledge level about heart failure management
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2675280
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2675280
# name: Most patients die from heart failure
# Source Vocabulary: OMIM
#
#
# ui: C2676080
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2676080
# name: CONGESTIVE HEART FAILURE AND BETA-BLOCKER RESPONSE, MODIFIER OF
# Source Vocabulary: OMIM
#
#
# ui: C2735646
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2735646
# name: Symptoms in heart failure patients:Find:Pt:^Patient:Ord:CMS Assessment
# Source Vocabulary: LNC
#
#
# ui: C2735648
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2735648
# name: Heart failure follow-up:Find:Pt:^Patient:Nom:CMS Assessment
# Source Vocabulary: LNC
#
#
# ui: C2739352
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2739352
# name: Heart failure in last 7D:Find:7D:^Patient:Ord:MDSv3
# Source Vocabulary: LNC
#
#
# ui: C2882272
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882272
# name: Combined systolic (congestive) and diastolic (congestive) heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C2882274
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882274
# name: Acute combined systolic and diastolic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2882275
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882275
# name: Chronic combined systolic and diastolic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2882276
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882276
# name: Acute on chronic combined systolic and diastolic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C2887331
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2887331
# name: Postprocedural heart failure following cardiac surgery
# Source Vocabulary: ICD10CM
#
#
# ui: C2887332
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2887332
# name: Postprocedural heart failure following other surgery
# Source Vocabulary: ICD10CM
#
#
# ui: C2984175
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2984175
# name: Date of First Ever Onset of Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C2984176
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2984176
# name: Date of Heart Failure Prompting Medical Attention
# Source Vocabulary: NCI
#
#
# ui: C3176374
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3176374
# name: Heart failure 4Y risk:Num:Pt:^Patient:Qn:Framingham.Kannel 1999
# Source Vocabulary: LNC
#
#
# *********
# Results for page 11
#
# ui: C3262555
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3262555
# name: Note:Find:Pt:{Setting}:Doc:Advanced heart failure and transplant cardiology
# Source Vocabulary: LNC
#
#
# ui: C3484105
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3484105
# name: Minnesota Living with Heart Failure Questionnaire:-:Pt:^Patient:-:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C3495064
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3495064
# name: Documentation of heart failure medication action plan
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3532174
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532174
# name: Fetal heart failure with redistribution of cardiac output
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3662013
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3662013
# name: High risk of heart failure, stage B
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3697987
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3697987
# name: Congestive heart failure as early postoperative complication
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3807342
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3807342
# name: Heart failure (more common in male patients)
# Source Vocabulary: OMIM
#
#
# ui: C3839467
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3839467
# name: Heart failure with reduced ejection fraction due to myocarditis
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3839695
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3839695
# name: Heart failure with reduced ejection fraction due to cardiomyopathy
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3844504
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3844504
# name: Patient does not have diagnosis of heart failure
# Source Vocabulary: LNC
#
#
# ui: C3845504
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3845504
# name: Exacerbation of CHF, fluid overload, heart failure
# Source Vocabulary: LNC
#
#
# ui: C3875278
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3875278
# name: Referral to heart failure exercise program declined
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3875346
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3875346
# name: Referral to heart failure exercise program not indicated
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3875353
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3875353
# name: Fetal heart failure due to extracardiac disease
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3897927
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3897927
# name: Physical Examination Findings of New or Worsening Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3898091
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898091
# name: Oral Diuretic Therapy Augmentation for Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3898637
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898637
# name: Lab Findings of New or Worsening Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3898697
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898697
# name: Intravenous Diuretic, Inotropic or Vasodilator Augmentation for Heart Failure
# Source Vocabulary: NCI
#
#
# ui: C3898898
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3898898
# name: Heart Failure by Non-invasive Diagnostic Technique
# Source Vocabulary: NCI
#
#
# ui: C4041295
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4041295
# name: Nutritional therapy for congestive heart failure done
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4047979
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4047979
# name: Congestive heart failure as post-operative complication of cardiac surgery
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4273448
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4273448
# name: Provision of written information about heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4280934
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4280934
# name: Reduced ejection fraction co-occurrent and due to chronic heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4303907
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4303907
# name: Congestive heart failure clinical management plan
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4319726
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4319726
# name: Minnesota Living with Heart Failure Questionnaire (MLHFQ)
# Source Vocabulary: MTH
#
#
# *********
# Results for page 12
#
# ui: C4321398
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4321398
# name: Minnesota Living with Heart Failure Questionnaire (MLHFQ) set
# Source Vocabulary: MTH
#
#
# ui: C4325535
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4325535
# name: Chylous pleural effusion due to congestive heart failure
# Source Vocabulary: SNOMEDCT_VET
#
#
# ui: C4483921
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483921
# name: Change in symptoms of heart failure compared with 2W ago
# Source Vocabulary: LNC
#
#
# ui: C4489293
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4489293
# name: Chronic cardiac condition (e.g., heart failure)
# Source Vocabulary: LNC
#
#
# ui: C4509223
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509223
# name: Heart failure with reduced ejection fraction [HFrEF]
# Source Vocabulary: ICD10CM
#
#
# ui: C4509226
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509226
# name: Heart failure with preserved ejection fraction [HFpEF]
# Source Vocabulary: ICD10CM
#
#
# ui: C4509227
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509227
# name: Combined systolic and diastolic left ventricular heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C4509228
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509228
# name: Heart failure with reduced ejection fraction and diastolic dysfunction
# Source Vocabulary: ICD10CM
#
#
# ui: C4509238
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4509238
# name: Acute on chronic isolated right heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C0155604
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155604
# name: malignant hypertensive heart and renal disease with congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C0392462
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0392462
# name: Benign hypertensive heart disease without congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0392463
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0392463
# name: Malignant hypertensive heart disease without congestive heart failure
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0865679
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0865679
# name: Acute pulmonary edema with heart disease NOS or heart failure
# Source Vocabulary: MTHICD9
#
#
# ui: C1394795
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1394795
# name: heart; decompensation, right ventricle (secondary to left heart failure)
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C2882082
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C2882082
# name: Hypertensive heart and chronic kidney disease without heart failure
# Source Vocabulary: ICD10CM
#
#
# ui: C3532229
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3532229
# name: Heart failure due to end stage congenital heart disease
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C3648845
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3648845
# name: hypertensive heart and chronic kidney disease without congestive heart failure
# Source Vocabulary: MEDCIN
#
#
# ui: C3839720
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3839720
# name: Heart failure with reduced ejection fraction due to heart valve disease
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C0155608
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155608
# name: Hypertensive heart and chronic kidney disease, benign, without heart failure and with chronic kidney disease stage I through stage IV, or unspecified
# Source Vocabulary: ICD9CM
#
#
# ui: C0155612
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0155612
# name: Hypertensive heart and chronic kidney disease, unspecified, without heart failure and with chronic kidney disease stage I through stage IV, or unspecified
# Source Vocabulary: ICD9CM
#
#
# ui: C0859775
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0859775
# name: Hypertensive heart and renal disease, unspec, w/o ment of congestive heart failure or renal failure
# Source Vocabulary: MTH
#
#
# ui: C1400067
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1400067
# name: hypertensive heart disease; with hypertensive kidney disease, with renal failure (without heart failure)
# Source Vocabulary: ICPC2ICD10ENG
#
#
# ui: C2047550
# ...
# Source Vocabulary: LNC
#
#
# ui: C4483940
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483940
# name: How would you feel if you had to spend the rest of your life with your heart failure the way it is right now
# Source Vocabulary: LNC
#
#
# ui: C4483941
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483941
# name: Felt discouraged or down in the dumps because of heart failure over the past 2W:Find:2W:^Patient:Ord:KCCQ
# Source Vocabulary: LNC
#
#
# ui: C4483943
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483943
# name: Participation in hobbies, recreational activities limited by heart failure over the past 2W:Find:2W:^Patient:Ord:KCCQ
# Source Vocabulary: LNC
#
#
# *********
# Results for page 16
#
# ui: C4483945
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483945
# name: Participation in working or doing household chores limited by heart failure over the past 2W:Find:2W:^Patient:Ord:KCCQ
# Source Vocabulary: LNC
#
#
# ui: C4483946
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483946
# name: Participation in working or doing household chores limited by heart failure over the past 2W
# Source Vocabulary: LNC
#
#
# ui: C4483947
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483947
# name: Participation in visiting family or friends out of your home limited by heart failure over the past 2W:Find:2W:^Patient:Ord:KCCQ
# Source Vocabulary: LNC
#
#
# ui: C4483948
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483948
# name: Participation in visiting family or friends out of your home limited by heart failure over the past 2W
# Source Vocabulary: LNC
#
#
# ui: C4483949
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483949
# name: Participation in intimate relationships with loved ones limited by heart failure over the past 2W:Find:2W:^Patient:Ord:KCCQ
# Source Vocabulary: LNC
#
#
# ui: C4483950
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483950
# name: Participation in intimate relationships with loved ones limited by heart failure over the past 2W
# Source Vocabulary: LNC
#
#
# ui: C3872824
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C3872824
# name: Assessment using congestive heart failure, hypertension, age 2, diabetes mellitus, stroke 2 - vascular disease, age, sex category score
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4318521
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4318521
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by causing swelling in your ankles or legs
# Source Vocabulary: LNC
#
#
# ui: C4318777
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4318777
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you stay in a hospital:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4319384
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4319384
# name: How would you feel if you had to spend the rest of your life with your heart failure the way it is right now:Find:Pt:^Patient:Ord:KCCQ
# Source Vocabulary: LNC
#
#
# ui: C4482638
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482638
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by costing you money for medical care
# Source Vocabulary: LNC
#
#
# ui: C4482640
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482640
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by giving you side effects from treatments
# Source Vocabulary: LNC
#
#
# ui: C4482828
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482828
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your sleeping well at night difficult
# Source Vocabulary: LNC
#
#
# ui: C4483095
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483095
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your working to earn a living difficult
# Source Vocabulary: LNC
#
#
# ui: C4483099
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483099
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your sexual activities difficult
# Source Vocabulary: LNC
#
#
# ui: C4483102
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483102
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you short of breath:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483103
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483103
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you short of breath
# Source Vocabulary: LNC
#
#
# ui: C4483106
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483106
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you stay in a hospital
# Source Vocabulary: LNC
#
#
# ui: C4483107
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483107
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you worry:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483108
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483108
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you worry
# Source Vocabulary: LNC
#
#
# ui: C4483109
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483109
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making it difficult for you to concentrate or remember things
# Source Vocabulary: LNC
#
#
# ui: C4483110
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483110
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you feel depressed:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483111
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483111
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you feel depressed
# Source Vocabulary: LNC
#
#
# ui: C4483116
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483116
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you tired, fatigued or low on energy
# Source Vocabulary: LNC
#
#
# ui: C0514536
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C0514536
# name: Promote optimal preload to improve contractility while minimizing heart failure (e.g., administer nitroglycerine and maintain pulmonary capillary/artery wedge pressure within prescribed range), as appropriate
# Source Vocabulary: NIC
#
#
# *********
# Results for page 17
#
# ui: C4049268
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4049268
# name: CHA2DS2-VASc score
# Source Vocabulary: SNOMEDCT_US
#
#
# ui: C4318522
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4318522
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your working around the house or yard difficult
# Source Vocabulary: LNC
#
#
# ui: C4318523
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4318523
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your relating to or doing things with your friends or family difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4318778
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4318778
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making it difficult for you to concentrate or remember things:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4319376
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4319376
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by costing you money for medical care:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482639
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482639
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by giving you side effects from treatments:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482641
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482641
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you feel you are a burden to your family or friends:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482642
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482642
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you feel you are a burden to your family or friends
# Source Vocabulary: LNC
#
#
# ui: C4482643
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482643
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you feel a loss of self-control in your life:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482644
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482644
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you feel a loss of self-control in your life
# Source Vocabulary: LNC
#
#
# ui: C4482821
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482821
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by causing swelling in your ankles or legs:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482822
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482822
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your walking about or climbing stairs difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482823
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482823
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your walking about or climbing stairs difficult
# Source Vocabulary: LNC
#
#
# ui: C4482824
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482824
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your working around the house or yard difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482825
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482825
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your going places away from home difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482826
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482826
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your going places away from home difficult
# Source Vocabulary: LNC
#
#
# ui: C4482827
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482827
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your sleeping well at night difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4482829
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4482829
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your relating to or doing things with your friends or family difficult
# Source Vocabulary: LNC
#
#
# ui: C4483094
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483094
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your working to earn a living difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483096
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483096
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your recreational pastimes, sports or hobbies difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483097
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483097
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your recreational pastimes, sports or hobbies difficult
# Source Vocabulary: LNC
#
#
# ui: C4483098
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483098
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making your sexual activities difficult:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483100
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483100
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you eat less of the foods you like:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C4483101
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483101
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you eat less of the foods you like
# Source Vocabulary: LNC
#
#
# ui: C4483113
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483113
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you sit or lie down to rest during the day:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# *********
# Results for page 18
#
# ui: C4483114
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483114
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you sit or lie down to rest during the day
# Source Vocabulary: LNC
#
#
# ui: C4483115
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4483115
# name: Did your heart failure prevent you from living as you wanted during the past M (4W) by making you tired, fatigued or low on energy:Find:1M:^Patient:Ord:MLHFQ
# Source Vocabulary: LNC
#
#
# ui: C1608455
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1608455
# name: Heart failure assessed (includes assessment of all the following components) (CAD): Blood pressure measured (2000F) Level of activity assessed (1003F) Clinical symptoms of volume overload (excess) assessed (1004F) Weight, recorded (2001F) Clinical signs of volume overload (excess) assessed (2002F)
# Source Vocabulary: CPT
#
#
# ui: C1608457
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1608457
# name: Written discharge instructions provided to heart failure patients discharged home (Instructions include all of the following components: activity level, diet, discharge medications, follow-up appointment, weight monitoring, what to do if symptoms worsen) (NMA-No Measure Associated)
# Source Vocabulary: CPT
#
#
# ui: C1738526
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C1738526
# name: Co-morbid conditions assessed (eg, includes assessment for presence or absence of: malignancy, liver disease, congestive heart failure, cerebrovascular disease, renal disease, chronic obstructive pulmonary disease, asthma, diabetes, other co-morbid conditions) (CAP)
# Source Vocabulary: CPT
#
#
# ui: C4067458
# uri: https://uts-ws.nlm.nih.gov/rest/content/2017AB/CUI/C4067458
# name: Documentation that the patient is on a statin medication or has documentation of a valid contraindication or exception to statin medications; contraindications/exceptions that can be defined by diagnosis codes include pregnancy during the measurement period, active liver disease, rhabdomyolysis, end stage renal disease on dialysis and heart failure; provider documented contraindications/exceptions include breastfeeding during the measurement period, woman of child-bearing age not actively taking birth control, allergy to statin, drug interaction (hiv protease inhibitors, nefazodone, cyclosporine, gemfibrozil, and danazol) and intolerance (with supporting documentation of trying a statin at least once within the last 5 years or diagnosis codes for myostitis or toxic myopathy related to drugs)
# Source Vocabulary: HCPCS
#
#
# *********
# Results for page 19
#
# ui: NONE
# name: NO RESULTS

# %%
import os
cwd = os.getcwd()

# %%
cwd

# %%
from umls.UMLSFinder import UMLSFinder
umls = UMLSFinder(ConfigReader().getValue('api_key'))

# %%
umls.search('heart failure')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-e29a65283d87> in <module>()
# ----> 1 umls.search('heart failure')
#
# ~/Documents/PycharmProjects/SmartAnno/SmartAnno/umls/UMLSFinder.py in search(self, input_phrase)
#      37             r = requests.get(UMLSFinder.uri + UMLSFinder.content_endpoint, params=query)
#      38             r.encoding = 'utf-8'
# ---> 39             items = json.loads(r.text)
#      40             jsonData = items["result"]
#      41             # print (json.dumps(items, indent = 4))
#
# ~/software/anaconda3/envs/tensorflow/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/software/anaconda3/envs/tensorflow/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/software/anaconda3/envs/tensorflow/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
